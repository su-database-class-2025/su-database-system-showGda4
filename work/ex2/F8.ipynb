# %% [markdown]
# # SQL for accessing spatial data on postgreSQL

# %% [markdown]
# データベースシステム講義資料
# version 0.0.1
# authors: H. Chenan & N. Tsutsumida
#
# Copyright (c) 2023 Narumasa Tsutsumida
# Released under the MIT license
# https://opensource.org/licenses/mit-license.php

# %% [markdown]
# ## Task

# %% [markdown]
# OpenStreetMapのデータを用いたテーマを自由に設定し、データを抽出し、結果を地図で示せ
#
# ・さいたま市内の銀行を抽出し、地図化する

# %% [markdown]
# ## prerequisites

# %%
import os
from sqlalchemy import create_engine
import pandas as pd
import geopandas as gpd
import numpy as np
import folium
pd.set_option('display.max_columns', 100)

# %%
def query_geopandas(sql, db):
    """
    Executes a SQL query on a postGIS and returns the result as a GeoPandas GeoDataFrame.

    Args:
        sql (str): The SQL query to execute.
        db (str): The name of the PostgreSQL database to connect to.

    Returns:
        geopandas.GeoDataFrame: The result of the SQL query as a GeoPandas GeoDataFrame.
    """
    DATABASE_URL = 'postgresql://postgres:postgres@postgis_container:5432/{}'.format(db)
    conn = create_engine(DATABASE_URL)
    query_result_gdf = gpd.GeoDataFrame.from_postgis(
        sql, conn, geom_col='way') #geom_col='way' when using osm_kanto, geom_col='geom' when using gisdb
    return query_result_gdf

# %% [markdown]
# ## Define a sql command

# %%
sql = """
    select pt.*
    from planet_osm_point pt, adm2 poly
    where pt.amenity='bank' and
    poly.name_2='Saitama' and
    st_within(pt.way,st_transform(poly.geom, 3857));
    """

# %% [markdown]
# ## Outputs

# %%
def display_interactive_map(gdf):
    if gdf.crs != 'EPSG:4326':
        gdf = gdf.to_crs(epsg=4326)
    # Create a base map
    m = folium.Map(location=[35.8616, 139.6455], zoom_start=12)  # You can modify the location as per your dataset

    # Add data points to the map
    for _, row in gdf.iterrows():
        coords = (row['way'].y, row['way'].x)
        folium.Marker(location=coords, popup=row['name']).add_to(m)

    return m

# %%
out = query_geopandas(sql,'gisdb')
map_display = display_interactive_map(out)
print(out)
display(map_display)
# Out:
#          osm_id access addr:housename addr:housenumber addr:interpolation  \
# 0    6661634972   None           None             None               None
# 1    8649514876   None           None             None               None
# 2    8758442700   None           None             None               None
# 3    5924444174   None           None             None               None
# 4    3718539586   None           None             None               None
# ..          ...    ...            ...              ...                ...
# 132  5832272187   None           None             None               None
# 133  7464450222   None           None             None               None
# 134  7464450318   None           None             None               None
# 135  8378221248   None           None             None               None
# 136  8395658122   None           None             None               None
#
#     admin_level aerialway aeroway amenity  area barrier bicycle  brand bridge  \
# 0          None      None    None    bank  None    None    None   None   None
# 1          None      None    None    bank  None    None    None   None   None
# 2          None      None    None    bank  None    None    None   None   None
# 3          None      None    None    bank  None    None    None   None   None
# 4          None      None    None    bank  None    None    None   None   None
# ..          ...       ...     ...     ...   ...     ...     ...    ...    ...
# 132        None      None    None    bank  None    None    None   None   None
# 133        None      None    None    bank  None    None    None   None   None
# 135  None  None       None  None         None             None    None  None
# 136  None  None       None  None         None             None    None  None
#
#     religion route service  shop sport surface  toll tourism tower:type  \
# 0       None  None    None  None  None    None  None    None       None
# 1       None  None    None  None  None    None  None    None       None
# 2       None  None    None  None  None    None  None    None       None
# 3       None  None    None  None  None    None  None    None       None
# 4       None  None    None  None  None    None  None    None       None
# ..       ...   ...     ...   ...   ...     ...   ...     ...        ...
# 132     None  None    None  None  None    None  None    None       None
# 133     None  None    None  None  None    None  None    None       None
# 134     None  None    None  None  None    None  None    None       None
# 135     None  None    None  None  None    None  None    None       None
# 136     None  None    None  None  None    None  None    None       None
#
#     tunnel water waterway wetland width  wood z_order  \
# 0     None  None     None    None  None  None    None
# 1     None  None     None    None  None  None    None
# 2     None  None     None    None  None  None    None
# 3     None  None     None    None  None  None    None
# 4     None  None     None    None  None  None    None
# ..     ...   ...      ...     ...   ...   ...     ...
# 132   None  None     None    None  None  None    None
# 133   None  None     None    None  None  None    None
# 134   None  None     None    None  None  None    None
# 135   None  None     None    None  None  None    None
# 136   None  None     None    None  None  None    None
#
#                                   way
# 0    POINT (15541007.925 4293497.816)
# 1    POINT (15544481.294 4293665.838)
# 2     POINT (15544485.68 4293730.565)
# 3    POINT (15545311.003 4293610.559)
# 4    POINT (15545099.061 4293212.078)
# ..                                ...
# 132  POINT (15545539.308 4279313.391)
# 133  POINT (15545433.176 4279608.529)
# 134  POINT (15545131.043 4279106.535)
# 135  POINT (15544821.887 4278491.453)
# 136  POINT (15545392.756 4279230.596)
#
# [137 rows x 70 columns]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fdc6ae1dc0a8961e9009690d73a37a39 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fdc6ae1dc0a8961e9009690d73a37a39&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fdc6ae1dc0a8961e9009690d73a37a39 = L.map(
#                 &quot;map_fdc6ae1dc0a8961e9009690d73a37a39&quot;,
#                 {
#                     center: [35.8616, 139.6455],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fcdcff149271d515df3b91d7a10ed69b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fcdcff149271d515df3b91d7a10ed69b.addTo(map_fdc6ae1dc0a8961e9009690d73a37a39);
#
#
#             var marker_b082f2e1c306e07aeef5c0faa8514911 = L.marker(
#                 [35.94821239973044, 139.60724949999997],
#                 {
# }
#             ).addTo(map_fdc6ae1dc0a8961e9009690d73a37a39);
#
#
#         var popup_57008a1521e3c1cede590e10fc292fec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2bbfcd190b29f63dcd833743c0810b6e = $(`&lt;div id=&quot;html_2bbfcd190b29f63dcd833743c0810b6e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;JAさいたま宮原支店&lt;/div&gt;`)[0];
#                 popup_57008a1521e3c1cede590e10fc292fec.setContent(html_2bbfcd190b29f63dcd833743c0810b6e);
#
#
#
#         marker_b082f2e1c306e07aeef5c0faa8514911.bindPopup(popup_57008a1521e3c1cede590e10fc292fec)
#         ;
#
#
#
#
#             var marker_78b2a5d8ebcc9468a4e4e31a3656f729 = L.marker(
#                 [35.949434299730555, 139.6384513],
#                 {
# }
#             ).addTo(map_fdc6ae1dc0a8961e9009690d73a37a39);
#
#
#         var popup_d59037bfa958ccca2774a179f9fafd31 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_30cab947888be70581264656cc179146 = $(`&lt;div id=&quot;html_30cab947888be70581264656cc179146&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;埼玉りそな銀行&lt;/div&gt;`)[0];
#                 popup_d59037bfa958ccca2774a179f9fafd31.setContent(html_30cab947888be70581264656cc179146);
#
#
#
#         marker_78b2a5d8ebcc9468a4e4e31a3656f729.bindPopup(popup_d59037bfa958ccca2774a179f9fafd31)
#         ;
#
#
#
#
#             var marker_5586b28bc8fd7a94988c58939bf99b4e = L.marker(
#                 [35.9499049997306, 139.63849069999998],
#                 {
# }
#             ).addTo(map_fdc6ae1dc0a8961e9009690d73a37a39);
#
#
#         var popup_0336f8093dd2a2152f7ab677290d536e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50fa2845f7fefdc07280aeec040160aa = $(`&lt;div id=&quot;html_50fa2845f7fefdc07280aeec040160aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;JAさいたま&lt;/div&gt;`)[0];
#                 popup_0336f8093dd2a2152f7ab677290d536e.setContent(html_50fa2845f7fefdc07280aeec040160aa);
#
#
#
#         marker_5586b28bc8fd7a94988c58939bf99b4e.bindPopup(popup_0336f8093dd2a2152f7ab677290d536e)
#         ;
#
#
#
#
#             var marker_aecdcb30951c55c6d8142e6e8f40e0f8 = L.marker(
#                 [35.949032299730504, 139.6459047],
#                 {
# }
#             ).addTo(map_fdc6ae1dc0a8961e9009690d73a37a39);
#
#
#         var popup_fb3439e4ce1ce987bffb38e0bf8e02a9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7c914e27c623b728b129eccde3537c3b = $(`&lt;div id=&quot;html_7c914e27c623b728b129eccde3537c3b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;川口信用金庫&lt;/div&gt;`)[0];
#                 popup_fb3439e4ce1ce987bffb38e0bf8e02a9.setContent(html_7c914e27c623b728b129eccde3537c3b);
#
#
#
#         marker_aecdcb30951c55c6d8142e6e8f40e0f8.bindPopup(popup_fb3439e4ce1ce987bffb38e0bf8e02a9)
#         ;
#
#
#
#
#             var marker_9255d2384bddf7e069ca06e62d8dfb4f = L.marker(
#                 [35.94613439973021, 139.6440008],
#                 {
# }
#             ).addTo(map_fdc6ae1dc0a8961e9009690d73a37a39);
#
#
#         var popup_db02e714076f72ae32e0a8d4d6cacd27 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a55411716645911592055f3d0a7ba0d4 = $(`&lt;div id=&quot;html_a55411716645911592055f3d0a7ba0d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;栃木銀行&lt;/div&gt;`)[0];
#                 popup_db02e714076f72ae32e0a8d4d6cacd27.setContent(html_a55411716645911592055f3d0a7ba0d4);
#
#
#
#         marker_9255d2384bddf7e069ca06e62d8dfb4f.bindPopup(popup_db02e714076f72ae32e0a8d4d6cacd27)
#         ;
#
#
#
#
#             var marker_960ec69653fab5e33d784c3d139216f2 = L.marker(
#                 [35.94783
